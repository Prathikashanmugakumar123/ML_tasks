# %%
from nltk.stem import PorterStemmer, LancasterStemmer

porter = PorterStemmer()
lancaster = LancasterStemmer()

word = "happiness"

print("Porter:", porter.stem(word))
print("Lancaster:", lancaster.stem(word))
# Out:
# Porter: happi
# Lancaster: happy

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\vignesh
# [nltk_data]     ARC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to C:\Users\vignesh
# [nltk_data]     ARC\AppData\Roaming\nltk_data...
# True

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

sentence = input("Enter sentence: ")

# Tokenization
tokens = word_tokenize(sentence.lower())

# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(word) for word in tokens]

print("Lemmas:", lemmas)

# Simple sentiment words
positive = ["good", "love", "happy", "like", "nice"]
negative = ["bad", "hate", "sad", "worst", "poor"]

pos = 0
neg = 0

# Sentiment check
for word in lemmas:
    if word in positive:
        pos += 1
    elif word in negative:
        neg += 1
# Result
if pos > neg:
    print("Sentiment: POSITIVE")
elif neg > pos:
    print("Sentiment: NEGATIVE ")
else:
    print("Sentiment: NEUTRAL ")
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\vignesh
# [nltk_data]     ARC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Enter sentence:  i like movie
# Lemmas: ['i', 'like', 'movie']
# Sentiment: POSITIVE
