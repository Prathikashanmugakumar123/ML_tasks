# %%
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
# Stock price data
data = [100, 102, 105, 107, 110]
# Create ARIMA model
model = ARIMA(data, order=(1, 1, 1))
model_fit = model.fit()
# Forecast next day price
forecast = model_fit.forecast(steps=3)
print("Forecasted stock price for next day:", forecast[0])
print("Forecasted stock price for next day:", forecast[1])
print("Forecasted stock price for next day:", forecast[2])
# Out:
# Forecasted stock price for next day: 112.46687377575057
# Forecasted stock price for next day: 114.93372812120444
# Forecasted stock price for next day: 117.40056303651464
